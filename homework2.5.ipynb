# %% [markdown]
# <a href="https://colab.research.google.com/github/KezhenLi/Homework2/blob/main/homework2.5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import numpy as np
import math
import pandas as pd
from matplotlib import pyplot as plt

# %%
 drive.mount('/content/drive')
 # !ls "/content/drive/My Drive/baseball_stats.csv” 
open('/content/drive/My Drive//baseball_stats.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /bin/bash: -c: line 0: unexpected EOF while looking for matching `"'
# /bin/bash: -c: line 1: syntax error: unexpected end of file
# <_io.TextIOWrapper name='/content/drive/My Drive//baseball_stats.csv' mode='r' encoding='UTF-8'>

# %%
read_file = '/content/drive/My Drive//baseball_stats.csv'
df_data = pd.read_csv(read_file)
angle_avg = df_data["launch_angle_avg"]
batting_avg = df_data["batting_avg"]
z = np.polyfit(angle_avg,batting_avg, 2)
p = np.poly1d(z)
print(p)

plt.scatter(angle_avg,batting_avg)
x = np.arange(-5,30,0.1)
y = -0.0001339*pow(x,2) + 0.002238*x + 0.2464
plt.plot(x,y,'r--')
plt.xlabel("angle_avg ")
plt.ylabel("batting_avg")
plt.title("angle_avg-batting_avg")
plt.show()

# The best average angle to succeed: y=-0.0001339x^2+0.002238x+0.2464, y'=0.0002678x+0.002238=0, x=8.357degrees
# x=10, y=-0.0001339x^2+0.002238x+0.2464=0.25539
# Out:
#             2
# -0.0001339 x + 0.002238 x + 0.2464
